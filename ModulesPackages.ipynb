# %% [markdown]
# # ModulesPackages

# %%
import numpy as np
import matplotlib.pyplot as matplot

grades = np.random.normal(70,40,1000)
np.mean(grades)
# Out:
# 69.08203556507378

# %%
matplot.hist(grades,50)
matplot.show()
